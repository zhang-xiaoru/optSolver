# %%
import numpy as np
from testing.objectives import Quadratic

# %%
test = Quadratic(
    name = 'test',
    x0 = 20 * np.random.rand(100) - 10,
    kappa=100,
    n=100
)

# %%
test.gradf(test.x0 + 1).shape
# Out:
# (100,)

# %%
import pandas as pd

pd.read_csv("./problem_memo_output/small/summary/dim_10_wolf.txt", delim_whitespace=True)
# Out:
# /var/folders/0z/279v044519x2vjld_knpc9q40000gn/T/ipykernel_4764/169329669.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   pd.read_csv("./problem_memo_output/small/summary/dim_10_wolf.txt", delim_whitespace=True)
#      #         m         f  |gradf|      iter  CPU_time
# 0  2.0 -0.289068  0.000019     55.0  0.035605       NaN
# 1  4.0 -0.289068  0.000017     36.0  0.001056       NaN
# 2  6.0 -0.289068  0.000009     30.0  0.001278       NaN
# 3  8.0 -0.289068  0.000007     30.0  0.001195       NaN
